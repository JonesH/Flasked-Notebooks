# %% [markdown]
# # Matplotlib Example

# %%
import time
import pylab as plt
import numpy as np

# %%
print(f'Graph generated at {time.asctime()}')
plt.hist(np.random.normal(0, 1, 10000), color=np.random.rand(3), bins=100)
plt.tight_layout(rect=[0, 0, 2.4, 0.8])
plt.show()
# Out:
# Graph generated at Sun Apr  1 12:37:55 2018
